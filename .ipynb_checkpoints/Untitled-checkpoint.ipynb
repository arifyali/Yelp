# %%
import pandas as pd

# %%
df = pd.read_csv('MedianValueSqFt_by_zip.csv', converters={'RegionID': lambda x: str(x)})

# %%
df2 = pd.read_csv('ACS.csv', converters={'zip.code.tabulation.area.': lambda x: str(x)})

# %%
df2.head()
# Out:
#    Unnamed: 0  X..B01003_001E  B01001_011E  B01001_035E  B02001_002E  \
# 0           1           18088          592          592        17408
# 1           2           40859         1294         1299        23919
# 2           3           53162         1508         1640        38809
# 3           4            6415          125          207         5621
# 4           5           28805          853          838        19336
#
#    B02001_003E  B02001_004E  B02001_005E  B02001_006E  B02001_007E ...  \
# 0          175            5            0            0          431 ...
# 1         1097           27           75            0         1520 ...
# 2         1913           75          629            0         3567 ...
# 3          154            0            0            0          519 ...
# 4         1002            0           26            0         5568 ...
#
#    B25002_002E  B25003_002E B25075_023E B25075_024E  B25075_025E  B25002_003E  \
# ...

# %%
df2['RegionID'] = df2['zip.code.tabulation.area.']

# %%
res_df = df.merge(df2, how='right', on='RegionID')

# %%
res_df.reset_index(drop=True).head()
# Out:
#   RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0    62080     11368.0  New York    NY  New York     Queens       1.0
# 1    84630     60629.0   Chicago    IL   Chicago       Cook       3.0
# 2    62037     11226.0  New York    NY  New York      Kings       5.0
# 3    62093     11385.0  New York    NY  New York     Queens       6.0
# 4    62031     11220.0  New York    NY  New York      Kings       7.0
#
#    2007-01  2007-02  2007-03 ...  B25002_002E  B25003_002E  B25075_023E  \
# 0    377.0    378.0    378.0 ...          979          868            0
# 1    207.0    208.0    208.0 ...           82           71            0
# 2    328.0    333.0    336.0 ...          826          625           10
# 3    350.0    349.0    349.0 ...          171          126            0
# 4    408.0    414.0    419.0 ...          362          336            0
#
#    B25075_024E  B25075_025E  B25002_003E  B25077_001E  B25064_001E  \
# ...

# %%
res_df.count()
# Out:
# RegionID                     33120
# RegionName                    4283
# City                          4283
# State                         4283
# Metro                         4115
# CountyName                    4283
# SizeRank                      4283
# 2007-01                       4168
# 2007-02                       4168
# 2007-03                       4168
# 2007-04                       4168
# 2007-05                       4168
# 2007-06                       4169
# 2007-07                       4169
# 2007-08                       4169
# 2007-09                       4169
# 2007-10                       4169
# 2007-11                       4169
# 2007-12                       4169
# 2008-01                       4169
# 2008-02                       4170
# 2008-03                       4170
# 2008-04                       4170
# 2008-05                       4170
# 2008-06                       4170
# 2008-07                       4170
# 2008-08                       4171
# ...

# %%
res_df.to_csv('right_joined_census.csv')
